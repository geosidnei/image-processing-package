# %%
print('oi')
# Out:
# oi

# %%
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
io.read_image('/home/sid/Imagens/green.jpeg')
io.read_image('/home/sid/Imagens/outono.jpeg')
# Out:
# array([[[244, 167,   1],
#         [249, 169,  10],
#         [255, 185,  35],
#         ...,
#         [236, 124,  14],
#         [232, 115,   2],
#         [237, 113,   0]],
#
#        [[248, 173,   0],
#         [245, 165,   0],
#         [255, 174,  16],
#         ...,
#         [221, 109,   7],
#         [231, 114,   8],
#         [235, 113,   4]],
#
#        [[220, 140,   0],
#         [230, 148,   0],
#         [249, 163,   0],
#         ...,
#         [246, 137,  36],
#         [219, 104,   0],
#         [223, 103,   0]],
#
#        ...,
#
#        [[130,  82,  10],
#         [129,  82,  14],
#         [117,  71,  11],
#         ...,
#         [ 47,   0,   0],
#         [ 57,   0,   0],
#         [ 70,   6,   4]],
#
#        [[140,  94,  19],
#         [131,  87,  14],
#         [127,  83,  18],
#         ...,
#         [ 63,   0,   0],
#         [ 76,  10,  11],
#         [114,  50,  50]],
#
#        [[144,  98,  21],
#         [128,  82,   7],
#         [127,  82,  14],
# ...

# %%
image1 = io.read_image('/home/sid/Imagens/green.jpeg')
image2 = io.read_image('/home/sid/Imagens/outono.jpeg')

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
combination.transfer_histogram(image1, image2)
# Out:
# /home/sid/anaconda3/lib/python3.9/site-packages/image_processing/processing/combination.py:16: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched_image = match_histograms(image1, image2, multichannel=True)
# array([[[142,  42,  51],
#         [145,  37,  47],
#         [125,  21,  28],
#         ...,
#         [103,   5,  11],
#         [101,   4,  10],
#         [101,   3,  12]],
#
#        [[118,  46,  26],
#         [121,  43,  25],
#         [103,  29,   8],
#         ...,
#         [103,   5,  11],
#         [ 98,   3,   8],
#         [ 98,   3,   8]],
#
#        [[ 92,  46,   5],
#         [ 92,  41,   2],
#         [ 56,  28,   0],
#         ...,
#         [ 60,   0,   0],
#         [ 56,   0,   0],
#         [ 56,   0,   0]],
#
#        ...,
#
#        [[154,  35,  29],
#         [142,  32,  22],
#         [ 56,   9,   0],
#         ...,
# ...

# %%
result_image = combination.transfer_histogram(image1, image2)
plot.plot_result(image1, image2, result_image)

# %%
''' Não consegui instalar a versão feita pelo colega RTaramaru e por mim
    O jeito foi instalar a versão da Professora Karina Tiemi Kato para produzir os resultados acima.
    Data da conclusão: Quinta-feira, 13 de outubro de 2022 às 14:50
'''
